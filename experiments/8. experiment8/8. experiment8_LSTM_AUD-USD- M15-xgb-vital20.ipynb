# %% [markdown]
# Implementation of Transformer Model on AUD-USD(D) prediction of the close price 1 day ahead based on data of previous 10 hours
#
# ## 1. Data Preparation
#
# ### 1.1 Read in data file

# %%
import talib as ta

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

import keras

# %%
data = pd.read_csv('AUD_USD_M15_TA_71.csv')
data.set_index('datetime', inplace=True)
data
# Out:
#                open     high      low    close  upperband  middleband  \
# datetime
# 2005-01-02  0.78230  0.78230  0.78230  0.78230        NaN         NaN
# 2005-01-02  0.78200  0.78280  0.78180  0.78230        NaN         NaN
# 2005-01-02  0.78180  0.78180  0.78180  0.78180        NaN         NaN
# 2005-01-02  0.78140  0.78160  0.78060  0.78060        NaN         NaN
# 2005-01-02  0.78080  0.78130  0.78080  0.78090        NaN         NaN
# ...             ...      ...      ...      ...        ...         ...
# 2021-02-28  0.77134  0.77135  0.77082  0.77134   0.773069    0.771351
# 2021-02-28  0.77129  0.77232  0.77125  0.77203   0.773103    0.771368
# 2021-02-28  0.77210  0.77337  0.77140  0.77294   0.773146    0.771378
# 2021-02-28  0.77290  0.77483  0.77258  0.77469   0.773693    0.771491
# 2021-02-28  0.77466  0.77591  0.77432  0.77564   0.774420    0.771663
#
#             lowerband      dema       ema        ht  ...      trix     ultosc  \
# datetime                                             ...
# 2005-01-02        NaN       NaN       NaN       NaN  ...       NaN        NaN
# 2005-01-02        NaN       NaN       NaN       NaN  ...       NaN        NaN
# 2005-01-02        NaN       NaN       NaN       NaN  ...       NaN        NaN
# 2005-01-02        NaN       NaN       NaN       NaN  ...       NaN        NaN
# 2005-01-02        NaN       NaN       NaN       NaN  ...       NaN        NaN
# ...               ...       ...       ...       ...  ...       ...        ...
# 2021-02-28   0.769633  0.769878  0.771787  0.771285  ... -0.026900  45.174271
# 2021-02-28   0.769632  0.770068  0.771806  0.771270  ... -0.026312  46.603642
# 2021-02-28   0.769609  0.770382  0.771897  0.771295  ... -0.025572  46.941583
# 2021-02-28   0.769289  0.770932  0.772120  0.771378  ... -0.024598  50.533858
# 2021-02-28   0.768906  0.771568  0.772402  0.771498  ... -0.023384  53.421648
#
#                 willr       atr      natr   trange  avgprice  medprice  \
# datetime
# 2005-01-02        NaN       NaN       NaN      NaN  0.782300  0.782300
# 2005-01-02        NaN       NaN       NaN  0.00100  0.782225  0.782300
# 2005-01-02        NaN       NaN       NaN  0.00050  0.781800  0.781800
# 2005-01-02        NaN       NaN       NaN  0.00120  0.781050  0.781100
# 2005-01-02        NaN       NaN       NaN  0.00070  0.780950  0.781050
# ...               ...       ...       ...      ...       ...       ...
# 2021-02-28 -51.048951  0.001270  0.164593  0.00053  0.771212  0.771085
# 2021-02-28 -34.965035  0.001261  0.163369  0.00107  0.771723  0.771785
# 2021-02-28 -13.752914  0.001291  0.166997  0.00197  0.772452  0.772385
# 2021-02-28  -2.504472  0.001331  0.171779  0.00225  0.773750  0.773705
# 2021-02-28  -4.047976  0.001342  0.172961  0.00159  0.775133  0.775115
#
#             typprice  wclprice
# datetime
# 2005-01-02  0.782300  0.782300
# 2005-01-02  0.782300  0.782300
# 2005-01-02  0.781800  0.781800
# 2005-01-02  0.780933  0.780850
# 2005-01-02  0.781000  0.780975
# ...              ...       ...
# 2021-02-28  0.771170  0.771212
# 2021-02-28  0.771867  0.771907
# 2021-02-28  0.772570  0.772663
# 2021-02-28  0.774033  0.774198
# 2021-02-28  0.775290  0.775377
#
# [407400 rows x 71 columns]

# %%
data.shape
# Out:
# (407400, 71)

# %%
# close(t)
# wclprice(t)
# typprice(t)
# avgprice(t)
# high(t)
# medprice(t)
# low(t)
# dx(t)
# trange(t-1)
# trange(t)
# trange(t-2)
# trange(t-3)
# bop(t-3)
# bop(t-2)
# dx(t-2)
# bop(t-1)
# bop(t)
# fastdrsi(t-3)
# macdhistext(t-3)

# %%
## xgboost
# wclprice(t)
# close(t)
# typprice(t)
# wclprice(t-1)
# avgprice(t)
# high(t)
# close(t-3)
# typprice(t-2)
# low(t)
# sma10(t)
# upperband(t)
# midprice(t-3)
# upperband(t-3)
# low(t-1)
# medprice(t)
# open(t-3)
# macdsignalfix(t)
# dema(t-3)
# roc(t-3)
# dema(t-2)

# %%
vital = ['wclprice', 'close', 'typprice', 'avgprice', 'high', 
         'low', 'sma10', 'upperband', 'midprice', 'medprice', 
         'open', 'macdsignalfix', 'dema', 'roc']

# %%
data_back = data
data = data[vital]
data.shape
# Out:
# (407400, 14)

# %%
data = data[-100000:]

# %% [markdown]
# ## 2. Data Processing

# %%
## drop rows with NANs
data.dropna(axis=0, inplace=True)
data = data.reset_index(drop=True)
print('shape of data: ', data.shape)
data
# Out:
# shape of data:  (100000, 14)
#        wclprice    close  typprice  avgprice     high      low     sma10  \
# 0      0.770723  0.77074  0.770717  0.770713  0.77076  0.77065  0.769702
# 1      0.770877  0.77092  0.770863  0.770825  0.77096  0.77071  0.769736
# 2      0.771020  0.77096  0.771040  0.771018  0.77128  0.77088  0.769766
# 3      0.771125  0.77120  0.771100  0.771075  0.77126  0.77084  0.769809
# 4      0.771005  0.77096  0.771020  0.771075  0.77124  0.77086  0.769831
# ...         ...      ...       ...       ...      ...      ...       ...
# 99995  0.771212  0.77134  0.771170  0.771212  0.77135  0.77082  0.773618
# 99996  0.771907  0.77203  0.771867  0.771723  0.77232  0.77125  0.773521
# 99997  0.772663  0.77294  0.772570  0.772452  0.77337  0.77140  0.773435
# 99998  0.774198  0.77469  0.774033  0.773750  0.77483  0.77258  0.773406
# 99999  0.775377  0.77564  0.775290  0.775133  0.77591  0.77432  0.773451
#
#        upperband  midprice  medprice     open  macdsignalfix      dema  \
# 0       0.771009  0.769660  0.770705  0.77070       0.000174  0.770340
# 1       0.771119  0.769700  0.770835  0.77071       0.000193  0.770450
# 2       0.771228  0.769860  0.771080  0.77095       0.000213  0.770552
# 3       0.771365  0.769860  0.771050  0.77100       0.000235  0.770678
# 4       0.771441  0.769860  0.771050  0.77124       0.000254  0.770752
# ...          ...       ...       ...      ...            ...       ...
# 99995   0.773069  0.771385  0.771085  0.77134      -0.001182  0.769878
# 99996   0.773103  0.771385  0.771785  0.77129      -0.001098  0.770068
# 99997   0.773146  0.771385  0.772385  0.77210      -0.000992  0.770382
# 99998   0.773693  0.772035  0.773705  0.77290      -0.000850  0.770932
# 99999   0.774420  0.772575  0.775115  0.77466      -0.000677  0.771568
#
#             roc
# 0      0.187183
# 1      0.200161
# 2      0.176715
# 3      0.213109
# 4      0.197546
# ...         ...
# 99995 -0.106196
# 99996  0.050542
# 99997  0.031060
# 99998  0.353645
# 99999  0.534011
#
# [100000 rows x 14 columns]

# %% [markdown]
# ### 2.1 Train - validation - test split

# %%
train_split_frac = 0.8
val_split_frac = 0.9

train_split = int(train_split_frac * int(data.shape[0]))  ## end of train index (exclusive)
val_split = int(val_split_frac * int(data.shape[0]))      ## end of val index (exclusive)

# %%
training_data = data[: train_split]
validation_data = data[train_split: val_split]
test_data = data[val_split:]

# %%
print('Shape of training_data:   ', training_data.shape)
print('Shape of validation_data: ', validation_data.shape)
print('Shape of test_data:       ', test_data.shape)
# Out:
# Shape of training_data:    (80000, 14)
# Shape of validation_data:  (10000, 14)
# Shape of test_data:        (10000, 14)

# %% [markdown]
# ### 2.2 Standardisation

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
training_data = scaler.fit_transform(training_data)
validation_data = scaler.transform(validation_data)
test_data = scaler.transform(test_data)

# %% [markdown]
# ### 2.3 Create dataset

# %%
step = 1
past = 24  #previous 6 hours
future = 1
learning_rate = 0.00001
batch_size = 256
epochs = 10000

y = data[['close']]

# %% [markdown]
# #### 2.3.1 Training dataset

# %%
train_y_start = past + future
train_y_end = train_y_start + train_split
x_train = training_data
y_train = y.iloc[train_y_start: train_y_end].values
sequence_length = int(past / step)
import tensorflow as tf
from tensorflow import keras

dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

# %% [markdown]
# #### 2.3.2 Validation dataset

# %%
val_y_start = train_y_end
val_y_end = train_y_start + val_split
x_val = validation_data
y_val = y.iloc[val_y_start: val_y_end].values
dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

# %% [markdown]
# #### 2.3.3 Testing dataset

# %%
x_end = len(test_data) - past - future
test_y_start = val_y_end
x_test = test_data[: x_end]
y_test = y.iloc[test_y_start: ].values
dataset_test = keras.preprocessing.timeseries_dataset_from_array(
    x_test,
    y_test,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=1,
)

# %%
for batch in dataset_train.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (256, 24, 14)
# Target shape: (256, 1)

# %%
len(y_test)
# Out:
# 9975

# %% [markdown]
# ## 3. Experiment: LSTM model

# %% [markdown]
# ### 3.1 LSTM

# %%
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential
import keras

# %%
inputs = keras.layers.Input(shape=(inputs.shape[1], inputs.shape[2]))
lstm_out = keras.layers.LSTM(200)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 24, 14)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 200)               172000
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 172,201
# Trainable params: 172,201
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3.1 Training

# %%
## call back
path_checkpoint_trans = "LSTM_200_xgb20.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=30)

modelckpt_callback_trans = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint_trans,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(dataset_train, 
                      epochs=10000, 
                      validation_data=dataset_val, 
                      callbacks=[es_callback, modelckpt_callback_trans],
                      verbose=2, 
                      shuffle=False)
# Out:
# Epoch 1/10000
# 313/313 - 45s - loss: 0.0961 - val_loss: 0.0166
#
# Epoch 00001: val_loss improved from inf to 0.01662, saving model to LSTM_200_xgb20.h5
# Epoch 2/10000
# 313/313 - 42s - loss: 0.0075 - val_loss: 0.0175
#
# Epoch 00002: val_loss did not improve from 0.01662
# Epoch 3/10000
# 313/313 - 43s - loss: 0.0057 - val_loss: 0.0165
#
# Epoch 00003: val_loss improved from 0.01662 to 0.01646, saving model to LSTM_200_xgb20.h5
# Epoch 4/10000
# 313/313 - 43s - loss: 0.0045 - val_loss: 0.0149
#
# Epoch 00004: val_loss improved from 0.01646 to 0.01491, saving model to LSTM_200_xgb20.h5
# Epoch 5/10000
# 313/313 - 42s - loss: 0.0035 - val_loss: 0.0132
#
# Epoch 00005: val_loss improved from 0.01491 to 0.01324, saving model to LSTM_200_xgb20.h5
# Epoch 6/10000
# 313/313 - 43s - loss: 0.0028 - val_loss: 0.0116
#
# Epoch 00006: val_loss improved from 0.01324 to 0.01161, saving model to LSTM_200_xgb20.h5
# Epoch 7/10000
# 313/313 - 42s - loss: 0.0022 - val_loss: 0.0101
#
# Epoch 00007: val_loss improved from 0.01161 to 0.01009, saving model to LSTM_200_xgb20.h5
# Epoch 8/10000
# 313/313 - 43s - loss: 0.0017 - val_loss: 0.0087
#
# Epoch 00008: val_loss improved from 0.01009 to 0.00869, saving model to LSTM_200_xgb20.h5
# Epoch 9/10000
# 313/313 - 42s - loss: 0.0013 - val_loss: 0.0074
#
# Epoch 00009: val_loss improved from 0.00869 to 0.00742, saving model to LSTM_200_xgb20.h5
# Epoch 10/10000
# 313/313 - 41s - loss: 0.0011 - val_loss: 0.0063
#
# Epoch 00010: val_loss improved from 0.00742 to 0.00628, saving model to LSTM_200_xgb20.h5
# Epoch 11/10000
# 313/313 - 43s - loss: 8.6296e-04 - val_loss: 0.0053
#
# Epoch 00011: val_loss improved from 0.00628 to 0.00530, saving model to LSTM_200_xgb20.h5
# Epoch 12/10000
# 313/313 - 43s - loss: 7.1962e-04 - val_loss: 0.0045
#
# Epoch 00012: val_loss improved from 0.00530 to 0.00448, saving model to LSTM_200_xgb20.h5
# Epoch 13/10000
# 313/313 - 43s - loss: 6.2435e-04 - val_loss: 0.0038
#
# Epoch 00013: val_loss improved from 0.00448 to 0.00384, saving model to LSTM_200_xgb20.h5
# Epoch 14/10000
# 313/313 - 43s - loss: 5.6085e-04 - val_loss: 0.0034
#
# Epoch 00014: val_loss improved from 0.00384 to 0.00338, saving model to LSTM_200_xgb20.h5
# Epoch 15/10000
# 313/313 - 43s - loss: 5.1563e-04 - val_loss: 0.0031
#
# Epoch 00015: val_loss improved from 0.00338 to 0.00307, saving model to LSTM_200_xgb20.h5
# Epoch 16/10000
# 313/313 - 42s - loss: 4.8075e-04 - val_loss: 0.0029
#
# Epoch 00016: val_loss improved from 0.00307 to 0.00289, saving model to LSTM_200_xgb20.h5
# Epoch 17/10000
# 313/313 - 44s - loss: 4.5230e-04 - val_loss: 0.0028
#
# Epoch 00017: val_loss improved from 0.00289 to 0.00281, saving model to LSTM_200_xgb20.h5
# Epoch 18/10000
# 313/313 - 42s - loss: 4.2822e-04 - val_loss: 0.0028
#
# Epoch 00018: val_loss improved from 0.00281 to 0.00281, saving model to LSTM_200_xgb20.h5
# Epoch 19/10000
# 313/313 - 42s - loss: 4.0709e-04 - val_loss: 0.0028
#
# Epoch 00019: val_loss did not improve from 0.00281
# Epoch 20/10000
# 313/313 - 43s - loss: 3.8790e-04 - val_loss: 0.0029
#
# Epoch 00020: val_loss did not improve from 0.00281
# Epoch 21/10000
# 313/313 - 43s - loss: 3.7006e-04 - val_loss: 0.0030
#
# Epoch 00021: val_loss did not improve from 0.00281
# Epoch 22/10000
# 313/313 - 45s - loss: 3.5337e-04 - val_loss: 0.0030
#
# Epoch 00022: val_loss did not improve from 0.00281
# Epoch 23/10000
# 313/313 - 44s - loss: 3.3774e-04 - val_loss: 0.0030
#
# Epoch 00023: val_loss did not improve from 0.00281
# Epoch 24/10000
# 313/313 - 46s - loss: 3.2309e-04 - val_loss: 0.0030
#
# Epoch 00024: val_loss did not improve from 0.00281
# Epoch 25/10000
# 313/313 - 43s - loss: 3.0923e-04 - val_loss: 0.0030
#
# Epoch 00025: val_loss did not improve from 0.00281
# Epoch 26/10000
# 313/313 - 42s - loss: 2.9596e-04 - val_loss: 0.0029
#
# Epoch 00026: val_loss did not improve from 0.00281
# Epoch 27/10000
# 313/313 - 42s - loss: 2.8310e-04 - val_loss: 0.0028
#
# Epoch 00027: val_loss did not improve from 0.00281
# Epoch 28/10000
# 313/313 - 41s - loss: 2.7058e-04 - val_loss: 0.0027
#
# Epoch 00028: val_loss improved from 0.00281 to 0.00271, saving model to LSTM_200_xgb20.h5
# Epoch 29/10000
# 313/313 - 41s - loss: 2.5840e-04 - val_loss: 0.0026
#
# Epoch 00029: val_loss improved from 0.00271 to 0.00259, saving model to LSTM_200_xgb20.h5
# Epoch 30/10000
# 313/313 - 41s - loss: 2.4661e-04 - val_loss: 0.0025
#
# Epoch 00030: val_loss improved from 0.00259 to 0.00247, saving model to LSTM_200_xgb20.h5
# Epoch 31/10000
# 313/313 - 41s - loss: 2.3531e-04 - val_loss: 0.0023
#
# Epoch 00031: val_loss improved from 0.00247 to 0.00234, saving model to LSTM_200_xgb20.h5
# Epoch 32/10000
# 313/313 - 41s - loss: 2.2461e-04 - val_loss: 0.0022
#
# Epoch 00032: val_loss improved from 0.00234 to 0.00221, saving model to LSTM_200_xgb20.h5
# Epoch 33/10000
# 313/313 - 41s - loss: 2.1455e-04 - val_loss: 0.0021
#
# Epoch 00033: val_loss improved from 0.00221 to 0.00209, saving model to LSTM_200_xgb20.h5
# Epoch 34/10000
# 313/313 - 41s - loss: 2.0517e-04 - val_loss: 0.0020
#
# Epoch 00034: val_loss improved from 0.00209 to 0.00197, saving model to LSTM_200_xgb20.h5
# Epoch 35/10000
# 313/313 - 41s - loss: 1.9647e-04 - val_loss: 0.0019
#
# Epoch 00035: val_loss improved from 0.00197 to 0.00186, saving model to LSTM_200_xgb20.h5
# Epoch 36/10000
# 313/313 - 41s - loss: 1.8842e-04 - val_loss: 0.0018
#
# Epoch 00036: val_loss improved from 0.00186 to 0.00176, saving model to LSTM_200_xgb20.h5
# Epoch 37/10000
# 313/313 - 41s - loss: 1.8098e-04 - val_loss: 0.0017
#
# Epoch 00037: val_loss improved from 0.00176 to 0.00167, saving model to LSTM_200_xgb20.h5
# Epoch 38/10000
# 313/313 - 41s - loss: 1.7409e-04 - val_loss: 0.0016
#
# Epoch 00038: val_loss improved from 0.00167 to 0.00158, saving model to LSTM_200_xgb20.h5
# Epoch 39/10000
# 313/313 - 41s - loss: 1.6770e-04 - val_loss: 0.0015
#
# Epoch 00039: val_loss improved from 0.00158 to 0.00150, saving model to LSTM_200_xgb20.h5
# Epoch 40/10000
# 313/313 - 41s - loss: 1.6173e-04 - val_loss: 0.0014
#
# Epoch 00040: val_loss improved from 0.00150 to 0.00142, saving model to LSTM_200_xgb20.h5
# Epoch 41/10000
# 313/313 - 41s - loss: 1.5615e-04 - val_loss: 0.0014
#
# Epoch 00041: val_loss improved from 0.00142 to 0.00135, saving model to LSTM_200_xgb20.h5
# Epoch 42/10000
# 313/313 - 41s - loss: 1.5091e-04 - val_loss: 0.0013
#
# Epoch 00042: val_loss improved from 0.00135 to 0.00128, saving model to LSTM_200_xgb20.h5
# Epoch 43/10000
# 313/313 - 41s - loss: 1.4596e-04 - val_loss: 0.0012
#
# Epoch 00043: val_loss improved from 0.00128 to 0.00122, saving model to LSTM_200_xgb20.h5
# Epoch 44/10000
# 313/313 - 41s - loss: 1.4127e-04 - val_loss: 0.0012
#
# Epoch 00044: val_loss improved from 0.00122 to 0.00116, saving model to LSTM_200_xgb20.h5
# Epoch 45/10000
# 313/313 - 41s - loss: 1.3682e-04 - val_loss: 0.0011
#
# Epoch 00045: val_loss improved from 0.00116 to 0.00110, saving model to LSTM_200_xgb20.h5
# Epoch 46/10000
# 313/313 - 41s - loss: 1.3258e-04 - val_loss: 0.0010
#
# Epoch 00046: val_loss improved from 0.00110 to 0.00104, saving model to LSTM_200_xgb20.h5
# Epoch 47/10000
# 313/313 - 41s - loss: 1.2852e-04 - val_loss: 9.8907e-04
#
# Epoch 00047: val_loss improved from 0.00104 to 0.00099, saving model to LSTM_200_xgb20.h5
# Epoch 48/10000
# 313/313 - 41s - loss: 1.2464e-04 - val_loss: 9.3757e-04
#
# Epoch 00048: val_loss improved from 0.00099 to 0.00094, saving model to LSTM_200_xgb20.h5
# Epoch 49/10000
# 313/313 - 39s - loss: 1.2092e-04 - val_loss: 8.8820e-04
#
# Epoch 00049: val_loss improved from 0.00094 to 0.00089, saving model to LSTM_200_xgb20.h5
# Epoch 50/10000
# 313/313 - 30s - loss: 1.1734e-04 - val_loss: 8.4088e-04
#
# Epoch 00050: val_loss improved from 0.00089 to 0.00084, saving model to LSTM_200_xgb20.h5
# Epoch 51/10000
# 313/313 - 33s - loss: 1.1389e-04 - val_loss: 7.9550e-04
#
# Epoch 00051: val_loss improved from 0.00084 to 0.00080, saving model to LSTM_200_xgb20.h5
# Epoch 52/10000
# 313/313 - 33s - loss: 1.1057e-04 - val_loss: 7.5198e-04
#
# Epoch 00052: val_loss improved from 0.00080 to 0.00075, saving model to LSTM_200_xgb20.h5
# Epoch 53/10000
# 313/313 - 32s - loss: 1.0734e-04 - val_loss: 7.1021e-04
#
# Epoch 00053: val_loss improved from 0.00075 to 0.00071, saving model to LSTM_200_xgb20.h5
# Epoch 54/10000
# 313/313 - 33s - loss: 1.0422e-04 - val_loss: 6.7009e-04
#
# Epoch 00054: val_loss improved from 0.00071 to 0.00067, saving model to LSTM_200_xgb20.h5
# Epoch 55/10000
# 313/313 - 33s - loss: 1.0118e-04 - val_loss: 6.3153e-04
#
# Epoch 00055: val_loss improved from 0.00067 to 0.00063, saving model to LSTM_200_xgb20.h5
# Epoch 56/10000
# 313/313 - 33s - loss: 9.8219e-05 - val_loss: 5.9441e-04
#
# Epoch 00056: val_loss improved from 0.00063 to 0.00059, saving model to LSTM_200_xgb20.h5
# Epoch 57/10000
# 313/313 - 33s - loss: 9.5321e-05 - val_loss: 5.5864e-04
#
# Epoch 00057: val_loss improved from 0.00059 to 0.00056, saving model to LSTM_200_xgb20.h5
# Epoch 58/10000
# 313/313 - 33s - loss: 9.2478e-05 - val_loss: 5.2413e-04
#
# Epoch 00058: val_loss improved from 0.00056 to 0.00052, saving model to LSTM_200_xgb20.h5
# Epoch 59/10000
# 313/313 - 32s - loss: 8.9681e-05 - val_loss: 4.9078e-04
#
# Epoch 00059: val_loss improved from 0.00052 to 0.00049, saving model to LSTM_200_xgb20.h5
# Epoch 60/10000
# 313/313 - 32s - loss: 8.6921e-05 - val_loss: 4.5850e-04
#
# Epoch 00060: val_loss improved from 0.00049 to 0.00046, saving model to LSTM_200_xgb20.h5
# Epoch 61/10000
# 313/313 - 32s - loss: 8.4189e-05 - val_loss: 4.2723e-04
#
# Epoch 00061: val_loss improved from 0.00046 to 0.00043, saving model to LSTM_200_xgb20.h5
# Epoch 62/10000
# 313/313 - 31s - loss: 8.1477e-05 - val_loss: 3.9687e-04
#
# Epoch 00062: val_loss improved from 0.00043 to 0.00040, saving model to LSTM_200_xgb20.h5
# Epoch 63/10000
# 313/313 - 32s - loss: 7.8777e-05 - val_loss: 3.6739e-04
#
# Epoch 00063: val_loss improved from 0.00040 to 0.00037, saving model to LSTM_200_xgb20.h5
# Epoch 64/10000
# 313/313 - 31s - loss: 7.6079e-05 - val_loss: 3.3869e-04
#
# Epoch 00064: val_loss improved from 0.00037 to 0.00034, saving model to LSTM_200_xgb20.h5
# Epoch 65/10000
# 313/313 - 27s - loss: 7.3377e-05 - val_loss: 3.1075e-04
#
# Epoch 00065: val_loss improved from 0.00034 to 0.00031, saving model to LSTM_200_xgb20.h5
# Epoch 66/10000
# 313/313 - 27s - loss: 7.0662e-05 - val_loss: 2.8349e-04
#
# Epoch 00066: val_loss improved from 0.00031 to 0.00028, saving model to LSTM_200_xgb20.h5
# Epoch 67/10000
# 313/313 - 27s - loss: 6.7924e-05 - val_loss: 2.5690e-04
#
# Epoch 00067: val_loss improved from 0.00028 to 0.00026, saving model to LSTM_200_xgb20.h5
# Epoch 68/10000
# 313/313 - 27s - loss: 6.5154e-05 - val_loss: 2.3091e-04
#
# Epoch 00068: val_loss improved from 0.00026 to 0.00023, saving model to LSTM_200_xgb20.h5
# Epoch 69/10000
# 313/313 - 27s - loss: 6.2342e-05 - val_loss: 2.0552e-04
#
# Epoch 00069: val_loss improved from 0.00023 to 0.00021, saving model to LSTM_200_xgb20.h5
# Epoch 70/10000
# 313/313 - 27s - loss: 5.9476e-05 - val_loss: 1.8070e-04
#
# Epoch 00070: val_loss improved from 0.00021 to 0.00018, saving model to LSTM_200_xgb20.h5
# Epoch 71/10000
# 313/313 - 27s - loss: 5.6542e-05 - val_loss: 1.5647e-04
#
# Epoch 00071: val_loss improved from 0.00018 to 0.00016, saving model to LSTM_200_xgb20.h5
# Epoch 72/10000
# 313/313 - 27s - loss: 5.3525e-05 - val_loss: 1.3289e-04
#
# Epoch 00072: val_loss improved from 0.00016 to 0.00013, saving model to LSTM_200_xgb20.h5
# Epoch 73/10000
# 313/313 - 27s - loss: 5.0408e-05 - val_loss: 1.1008e-04
#
# Epoch 00073: val_loss improved from 0.00013 to 0.00011, saving model to LSTM_200_xgb20.h5
# Epoch 74/10000
# 313/313 - 27s - loss: 4.7174e-05 - val_loss: 8.8298e-05
#
# Epoch 00074: val_loss improved from 0.00011 to 0.00009, saving model to LSTM_200_xgb20.h5
# Epoch 75/10000
# 313/313 - 27s - loss: 4.3807e-05 - val_loss: 6.7957e-05
#
# Epoch 00075: val_loss improved from 0.00009 to 0.00007, saving model to LSTM_200_xgb20.h5
# Epoch 76/10000
# 313/313 - 27s - loss: 4.0298e-05 - val_loss: 4.9662e-05
#
# Epoch 00076: val_loss improved from 0.00007 to 0.00005, saving model to LSTM_200_xgb20.h5
# Epoch 77/10000
# 313/313 - 27s - loss: 3.6657e-05 - val_loss: 3.4173e-05
#
# Epoch 00077: val_loss improved from 0.00005 to 0.00003, saving model to LSTM_200_xgb20.h5
# Epoch 78/10000
# 313/313 - 27s - loss: 3.2918e-05 - val_loss: 2.2317e-05
#
# Epoch 00078: val_loss improved from 0.00003 to 0.00002, saving model to LSTM_200_xgb20.h5
# Epoch 79/10000
# 313/313 - 27s - loss: 2.9154e-05 - val_loss: 1.4721e-05
#
# Epoch 00079: val_loss improved from 0.00002 to 0.00001, saving model to LSTM_200_xgb20.h5
# Epoch 80/10000
# 313/313 - 28s - loss: 2.5483e-05 - val_loss: 1.0993e-05
#
# Epoch 00080: val_loss improved from 0.00001 to 0.00001, saving model to LSTM_200_xgb20.h5
# Epoch 81/10000
# 313/313 - 28s - loss: 2.2161e-05 - val_loss: 9.0396e-06
#
# Epoch 00081: val_loss improved from 0.00001 to 0.00001, saving model to LSTM_200_xgb20.h5
# Epoch 82/10000
# 313/313 - 28s - loss: 1.9509e-05 - val_loss: 6.3896e-06
#
# Epoch 00082: val_loss improved from 0.00001 to 0.00001, saving model to LSTM_200_xgb20.h5
# Epoch 83/10000
# 313/313 - 29s - loss: 1.7653e-05 - val_loss: 4.1613e-06
#
# Epoch 00083: val_loss improved from 0.00001 to 0.00000, saving model to LSTM_200_xgb20.h5
# Epoch 84/10000
# 313/313 - 28s - loss: 1.6582e-05 - val_loss: 4.3744e-06
#
# Epoch 00084: val_loss did not improve from 0.00000
# Epoch 85/10000
# 313/313 - 27s - loss: 1.6121e-05 - val_loss: 5.3419e-06
#
# Epoch 00085: val_loss did not improve from 0.00000
# Epoch 86/10000
# 313/313 - 27s - loss: 1.5859e-05 - val_loss: 6.4500e-06
#
# Epoch 00086: val_loss did not improve from 0.00000
# Epoch 87/10000
# 313/313 - 28s - loss: 1.5561e-05 - val_loss: 7.3184e-06
#
# Epoch 00087: val_loss did not improve from 0.00000
# Epoch 88/10000
# 313/313 - 28s - loss: 1.5144e-05 - val_loss: 7.9066e-06
#
# Epoch 00088: val_loss did not improve from 0.00000
# Epoch 89/10000
# 313/313 - 28s - loss: 1.4645e-05 - val_loss: 8.3686e-06
#
# Epoch 00089: val_loss did not improve from 0.00000
# Epoch 90/10000
# 313/313 - 28s - loss: 1.4114e-05 - val_loss: 8.7758e-06
#
# Epoch 00090: val_loss did not improve from 0.00000
# Epoch 91/10000
# 313/313 - 28s - loss: 1.3571e-05 - val_loss: 9.1177e-06
#
# Epoch 00091: val_loss did not improve from 0.00000
# Epoch 92/10000
# 313/313 - 28s - loss: 1.3019e-05 - val_loss: 9.3532e-06
#
# Epoch 00092: val_loss did not improve from 0.00000
# Epoch 93/10000
# 313/313 - 28s - loss: 1.2453e-05 - val_loss: 9.4393e-06
#
# Epoch 00093: val_loss did not improve from 0.00000
# Epoch 94/10000
# 313/313 - 28s - loss: 1.1869e-05 - val_loss: 9.3450e-06
#
# Epoch 00094: val_loss did not improve from 0.00000
# Epoch 95/10000
# 313/313 - 28s - loss: 1.1261e-05 - val_loss: 9.0553e-06
#
# Epoch 00095: val_loss did not improve from 0.00000
# Epoch 96/10000
# 313/313 - 27s - loss: 1.0627e-05 - val_loss: 8.5768e-06
#
# Epoch 00096: val_loss did not improve from 0.00000
# Epoch 97/10000
# 313/313 - 28s - loss: 9.9669e-06 - val_loss: 7.9328e-06
#
# Epoch 00097: val_loss did not improve from 0.00000
# Epoch 98/10000
# 313/313 - 28s - loss: 9.2821e-06 - val_loss: 7.1489e-06
#
# Epoch 00098: val_loss did not improve from 0.00000
# Epoch 99/10000
# 313/313 - 28s - loss: 8.5768e-06 - val_loss: 6.2348e-06
#
# Epoch 00099: val_loss did not improve from 0.00000
# Epoch 100/10000
# 313/313 - 27s - loss: 7.8640e-06 - val_loss: 5.2028e-06
#
# Epoch 00100: val_loss did not improve from 0.00000
# Epoch 101/10000
# 313/313 - 28s - loss: 7.1740e-06 - val_loss: 4.1683e-06
#
# Epoch 00101: val_loss did not improve from 0.00000
# Epoch 102/10000
# 313/313 - 28s - loss: 6.5507e-06 - val_loss: 3.3395e-06
#
# Epoch 00102: val_loss improved from 0.00000 to 0.00000, saving model to LSTM_200_xgb20.h5
# Epoch 103/10000
# 313/313 - 28s - loss: 6.0092e-06 - val_loss: 2.7889e-06
#
# Epoch 00103: val_loss improved from 0.00000 to 0.00000, saving model to LSTM_200_xgb20.h5
# Epoch 104/10000
# 313/313 - 28s - loss: 5.5396e-06 - val_loss: 2.4242e-06
#
# Epoch 00104: val_loss improved from 0.00000 to 0.00000, saving model to LSTM_200_xgb20.h5
# Epoch 105/10000
# 313/313 - 28s - loss: 5.1418e-06 - val_loss: 2.1828e-06
#
# Epoch 00105: val_loss improved from 0.00000 to 0.00000, saving model to LSTM_200_xgb20.h5
# Epoch 106/10000
# 313/313 - 29s - loss: 4.7728e-06 - val_loss: 2.0091e-06
#
# Epoch 00106: val_loss improved from 0.00000 to 0.00000, saving model to LSTM_200_xgb20.h5
# Epoch 107/10000
# 313/313 - 28s - loss: 4.4126e-06 - val_loss: 1.9301e-06
#
# Epoch 00107: val_loss improved from 0.00000 to 0.00000, saving model to LSTM_200_xgb20.h5
# Epoch 108/10000
# 313/313 - 28s - loss: 4.1038e-06 - val_loss: 1.8859e-06
#
# Epoch 00108: val_loss improved from 0.00000 to 0.00000, saving model to LSTM_200_xgb20.h5
# Epoch 109/10000
# 313/313 - 29s - loss: 3.8386e-06 - val_loss: 1.8246e-06
#
# Epoch 00109: val_loss improved from 0.00000 to 0.00000, saving model to LSTM_200_xgb20.h5
# Epoch 110/10000
# 313/313 - 27s - loss: 3.5730e-06 - val_loss: 2.1392e-06
#
# Epoch 00110: val_loss did not improve from 0.00000
# Epoch 111/10000
# 313/313 - 28s - loss: 3.3091e-06 - val_loss: 3.6113e-06
# Epoch 00111: val_loss did not improve from 0.00000
# Epoch 112/10000
# 313/313 - 28s - loss: 3.1273e-06 - val_loss: 6.6264e-06
#
# Epoch 00112: val_loss did not improve from 0.00000
# Epoch 113/10000
# 313/313 - 28s - loss: 3.1757e-06 - val_loss: 1.0703e-05
#
# Epoch 00113: val_loss did not improve from 0.00000
# Epoch 114/10000
# 313/313 - 29s - loss: 3.4280e-06 - val_loss: 1.4327e-05
#
# Epoch 00114: val_loss did not improve from 0.00000
# Epoch 115/10000
# 313/313 - 29s - loss: 3.5171e-06 - val_loss: 1.4961e-05
#
# Epoch 00115: val_loss did not improve from 0.00000
# Epoch 116/10000
# 313/313 - 29s - loss: 3.2949e-06 - val_loss: 1.2854e-05
#
# Epoch 00116: val_loss did not improve from 0.00000
# Epoch 117/10000
# 313/313 - 28s - loss: 2.9627e-06 - val_loss: 1.1762e-05
#
# Epoch 00117: val_loss did not improve from 0.00000
# Epoch 118/10000
# 313/313 - 27s - loss: 2.8439e-06 - val_loss: 1.3077e-05
#
# Epoch 00118: val_loss did not improve from 0.00000
# Epoch 119/10000
# 313/313 - 29s - loss: 3.0046e-06 - val_loss: 1.6761e-05
#
# Epoch 00119: val_loss did not improve from 0.00000
# Epoch 120/10000
# 313/313 - 28s - loss: 3.2985e-06 - val_loss: 2.1252e-05
#
# Epoch 00120: val_loss did not improve from 0.00000
# Epoch 121/10000
# 313/313 - 28s - loss: 3.3378e-06 - val_loss: 1.9807e-05
#
# Epoch 00121: val_loss did not improve from 0.00000
# Epoch 122/10000
# 313/313 - 27s - loss: 2.8982e-06 - val_loss: 1.5364e-05
#
# Epoch 00122: val_loss did not improve from 0.00000
# Epoch 123/10000
# 313/313 - 27s - loss: 2.6005e-06 - val_loss: 1.5319e-05
#
# Epoch 00123: val_loss did not improve from 0.00000
# Epoch 124/10000
# 313/313 - 27s - loss: 2.8213e-06 - val_loss: 2.0833e-05
#
# Epoch 00124: val_loss did not improve from 0.00000
# Epoch 125/10000
# 313/313 - 27s - loss: 3.3276e-06 - val_loss: 2.9349e-05
#
# Epoch 00125: val_loss did not improve from 0.00000
# Epoch 126/10000
# 313/313 - 27s - loss: 3.3205e-06 - val_loss: 2.3707e-05
#
# Epoch 00126: val_loss did not improve from 0.00000
# Epoch 127/10000
# 313/313 - 27s - loss: 2.6048e-06 - val_loss: 1.5945e-05
#
# Epoch 00127: val_loss did not improve from 0.00000
# Epoch 128/10000
# 313/313 - 27s - loss: 2.3321e-06 - val_loss: 1.6801e-05
#
# Epoch 00128: val_loss did not improve from 0.00000
# Epoch 129/10000
# 313/313 - 29s - loss: 2.8259e-06 - val_loss: 2.7696e-05
#
# Epoch 00129: val_loss did not improve from 0.00000
# Epoch 130/10000
# 313/313 - 28s - loss: 3.5887e-06 - val_loss: 4.0200e-05
#
# Epoch 00130: val_loss did not improve from 0.00000
# Epoch 131/10000
# 313/313 - 27s - loss: 3.2521e-06 - val_loss: 2.1935e-05
#
# Epoch 00131: val_loss did not improve from 0.00000
# Epoch 132/10000
# 313/313 - 27s - loss: 2.1473e-06 - val_loss: 1.3080e-05
#
# Epoch 00132: val_loss did not improve from 0.00000
# Epoch 133/10000
# 313/313 - 27s - loss: 2.0706e-06 - val_loss: 1.6140e-05
#
# Epoch 00133: val_loss did not improve from 0.00000
# Epoch 134/10000
# 313/313 - 27s - loss: 2.9527e-06 - val_loss: 3.6291e-05
#
# Epoch 00134: val_loss did not improve from 0.00000
# Epoch 135/10000
# 313/313 - 27s - loss: 4.0547e-06 - val_loss: 5.1206e-05
#
# Epoch 00135: val_loss did not improve from 0.00000
# Epoch 136/10000
# 313/313 - 27s - loss: 3.1998e-06 - val_loss: 1.5996e-05
#
# Epoch 00136: val_loss did not improve from 0.00000
# Epoch 137/10000
# 313/313 - 27s - loss: 1.7385e-06 - val_loss: 9.0142e-06
#
# Epoch 00137: val_loss did not improve from 0.00000
# Epoch 138/10000
# 313/313 - 27s - loss: 1.8017e-06 - val_loss: 1.2551e-05
#
# Epoch 00138: val_loss did not improve from 0.00000
# Epoch 139/10000
# 313/313 - 27s - loss: 2.8553e-06 - val_loss: 3.6333e-05
#
# Epoch 00139: val_loss did not improve from 0.00000

# %% [markdown]
# ### 3.2 Train and validation losses

# %%
train_loss_1 = history.history['loss']
val_loss_1 = history.history['val_loss']
plt.plot(train_loss_1, label='train loss', c='orange')
plt.plot(val_loss_1, label='val loss', c='blue')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### 3.4 Evaluation

# %%
test_prediction_1 = []
test_actual = []
for x, y in dataset_test:
    test_actual.append(y[0][0])
    predict_res = model.predict(x)[0][0]
    test_prediction_1.append(predict_res)
test_prediction_1 = np.array(test_prediction_1)
test_actual = np.array(test_actual)

# %%
len(test_prediction_1)
# Out:
# 9952

# %%
len(test_actual)
# Out:
# 9952

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

rmse1 = mean_squared_error(test_actual, test_prediction_1, squared=False)
mape1 = mean_absolute_percentage_error(test_actual, test_prediction_1)
mae1 = mean_absolute_error(test_actual, test_prediction_1)

print('result evaluation')
print('RMSE: ', rmse1)
print('MAPE: ', mape1)
print('MAE:  ', mae1)
# Out:
# result evaluation
# RMSE:  0.007591320840921745
# MAPE:  0.009990158701833085
# MAE:   0.00748833293062506

# %%
x_axis = [x for x in range(test_actual.shape[0])]
plt.figure(figsize=(20,6))

sns.lineplot(x=x_axis, y=test_actual, label='actual close price', linewidth=2)
sns.lineplot(x=x_axis, y=test_prediction_1, label='predicted close price', linewidth=2)
plt.legend()
plt.show()
